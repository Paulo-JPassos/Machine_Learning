# %% [markdown]
# <a href="https://colab.research.google.com/github/Paulo-JPassos/Machine_Learning/blob/main/segmentacao_por_cor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Segmentação por Cor (HSV)
import cv2
import matplotlib.pyplot as plt
import numpy as np
from urllib.request import urlopen

url = "https://raw.githubusercontent.com/opencv/opencv/master/samples/data/fruits.jpg"

resp = urlopen(url)
image = np.asarray(bytearray(resp.read()), dtype=np.uint8)

img = cv2.imdecode(image, cv2.IMREAD_COLOR)

img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Faixa do vermelho
lower_red = np.array([0,100,100])
upper_red = np.array([10,255,255])

mask = cv2.inRange(
    hsv,
    lower_red,
    upper_red
)

result = cv2.bitwise_and(
    img_rgb,
    img_rgb,
    mask=mask
)

plt.figure(figsize=(15,5))

plt.subplot(131)
plt.imshow(img_rgb)
plt.title("Original")

plt.subplot(132)
plt.imshow(mask, cmap='gray')
plt.title("Máscara")

plt.subplot(133)
plt.imshow(result)
plt.title("Objetos Vermelhos")

plt.show()
